# %%
from SameEventVisualizer import draw

PATH='/mnt/atlas01/projects/legend/data/com/raw/2022-04-13-sipm-test'
lh5_file=PATH+'/run007/20220422-131537-m6-muon-amajl2-mmaj4-es2000.lh5'
channel_map=PATH+'/channel-map.json'

# %%
draw(lh5_file, channel_map, entries=[5,2])

# %%
draw(lh5_file, channel_map, entries=[5,2], channel_mask=[0,1,7,13,22,29,4])
