# %%
from pe_spectrum import draw
import os, re, json
Path='/home/ge35miw/Tasks/Pe_Spectrum/'
pat='run\d{3}'
channel_map='/mnt/atlas01/projects/legend/data/com/raw/2022-04-13-sipm-test/channel-map.json'
with open(channel_map, 'r') as f:
    c_names=list(json.load(f)['hardware_configuration']['channel_map'].keys())
    
files=[Path+f'{name}/{name}.lh5' for name in os.listdir(Path) if not re.findall(pat,name)==[]]

# %%
for file in files:
    print(re.search(pat, file)[0]+':')
    draw(file, channels=c_names, draw_spectrum=True, draw_tp_hist=False)
    break
# Out:
# run007:

# %%
c_names
# Out:
# ['ch000',
#  'ch001',
#  'ch002',
#  'ch003',
#  'ch004',
#  'ch005',
#  'ch007',
#  'ch008',
#  'ch009',
#  'ch010',
#  'ch011',
#  'ch012',
#  'ch013',
#  'ch014',
#  'ch015',
#  'ch016',
#  'ch017',
#  'ch018',
#  'ch019',
#  'ch020',
#  'ch021',
#  'ch022',
#  'ch023',
#  'ch024',
#  'ch025',
#  'ch026',
#  'ch027',
#  'ch028',
#  'ch029',
#  'ch030',
#  'ch031',
#  'ch032']
