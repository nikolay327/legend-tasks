# %%
from pe_spectrum import draw
file='/home/ge35miw/Tasks/DSP_practice/processed_data.lh5'

# %%
draw(file, channels=['ch001', 'ch000', 'ch003', 'ch007', 'ch015'], draw_spectrum=True, draw_tp_hist=True)
