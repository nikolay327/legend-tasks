# %%
from pe_spectrum import draw
file='/home/ge35miw/Tasks/DSP_practice/processed_data.lh5'

# %%
draw(file, channels=['ch001', 'ch000', 'ch003', 'ch004', 'ch005'], dt=16)

# %%
draw(file, channels=['ch001', 'ch000', 'ch003', 'ch004', 'ch005'], dt=16, draw_spectrum=False, trigger_pos_hist=True)
